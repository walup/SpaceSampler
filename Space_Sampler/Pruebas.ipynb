# %%
#Importamos la clase implementada para muestrear puntos de un espacio
from SpaceSampler import SpaceSampler
import matplotlib.pyplot as plt
#Importamos los tipos de distancia, hasta ahora solo hay Euclidiana, Wasserstein y Aitchinson
from DistanceType import DistanceType
import numpy as np

# %% [markdown]
# #### Ejemplificación de uso del muestreo de puntos

# %% [markdown]
# #### Distancia euclidiana
# ##### Bola

# %%
#Primero como ejemplo obtengamos puntos en una bola centrada en [3,3] y con radio 3
center = [3,3]
radius = 3
nPoints = 1000
distanceType = DistanceType.EUCLIDEAN_DISTANCE
spSamp = SpaceSampler()


ballPoints = spSamp.sampleBallPoints(center,radius,nPoints, distanceType)

# %%
#Vamos a graficar
plt.figure()
plt.plot(ballPoints[:,0], ballPoints[:,1], color = "#2fcaf5", marker = "o", linestyle = "none")
plt.axis('equal');

# %% [markdown]
# ##### Anillo

# %%
#Ahora vamos a obtener los puntos de un anillo cuyo radio interior es 1 y radio exterior es 3
center = [3,3]
radius1 = 1
radius2 = 3
distanceType = DistanceType.EUCLIDEAN_DISTANCE

annulusPoints = spSamp.sampleAnnulusPoints(center, radius1, radius2, nPoints, distanceType)

# %%
plt.figure()
plt.plot(annulusPoints[:,0], annulusPoints[:,1], color = "#2fcaf5", marker = "o", linestyle = "none")
plt.axis('equal');

# %% [markdown]
# ##### Perímetro

# %%
center = [3,3]
radius = 3
nPoints = 1000
distanceType = DistanceType.EUCLIDEAN_DISTANCE
spSamp = SpaceSampler()


perimeterPoints = spSamp.samplePerimeterPoints(center,radius,nPoints,distanceType)

# %%
plt.figure()
plt.plot(perimeterPoints[:,0], perimeterPoints[:,1], color = "#2fcaf5", marker = "o", linestyle = "none")
plt.axis('equal');

# %% [markdown]
# #### Distancia Wasserstein

# %% [markdown]
# ##### Bola

# %%
center = [0.5,0.5]
radius = 0.2
nPoints = 1000
distanceType = DistanceType.WASSERSTEIN_DISTANCE
spSamp = SpaceSampler()


ballPoints = spSamp.sampleBallPoints(center,radius,nPoints, distanceType)

# %%
plt.figure()
plt.plot(ballPoints[:,0], ballPoints[:,1], color = "#2fcaf5", marker = "o", linestyle = "none")
plt.axis('equal');

# %% [markdown]
# ##### Anillo

# %%
#Ahora vamos a obtener los puntos de un anillo cuyo radio interior es 1 y radio exterior es 3
center = [0.5,0.5]
radius1 = 0.2
radius2 = 0.3
nPoints = 10000
distanceType = DistanceType.WASSERSTEIN_DISTANCE

annulusPoints = spSamp.sampleAnnulusPoints(center, radius1, radius2, nPoints, distanceType)

# %%
plt.figure()
plt.plot(annulusPoints[:,0], annulusPoints[:,1], color = "#2fcaf5", marker = "o", linestyle = "none")
plt.axis('equal');

# %% [markdown]
# ##### Perímetro

# %%
center = [0.5,0.5]
radius = 0.3
nPoints = 1000
distanceType = DistanceType.WASSERSTEIN_DISTANCE
spSamp = SpaceSampler()

epsilon = 0.01
perimeterPoints = spSamp.samplePerimeterPoints(center,radius,nPoints,distanceType, epsilon)

# %%
plt.figure()
plt.plot(perimeterPoints[:,0], perimeterPoints[:,1], color = "#2fcaf5", marker = "o", linestyle = "none")
plt.axis('equal');

# %% [markdown]
# #### Distancia Aitchinson
#
# ##### Bola

# %%
center = [0.5,0.5]
radius = 0.2
nPoints = 10000
distanceType = DistanceType.AITCHINSON_DISTANCE
spSamp = SpaceSampler()


ballPoints = spSamp.sampleBallPoints(center,radius,nPoints, distanceType)

# %%
plt.figure()
plt.plot(ballPoints[:,0], ballPoints[:,1], color = "#2fcaf5", marker = "o", linestyle = "none")
plt.axis('equal');

# %% [markdown]
# ##### Anillo

# %%
#Ahora vamos a obtener los puntos de un anillo cuyo radio interior es 1 y radio exterior es 3
center = [0.5,0.5]
radius1 = 0.2
radius2 = 0.3
nPoints = 1000
distanceType = DistanceType.AITCHINSON_DISTANCE

annulusPoints = spSamp.sampleAnnulusPoints(center, radius1, radius2, nPoints, distanceType)

# %%
plt.figure()
plt.plot(annulusPoints[:,0], annulusPoints[:,1], color = "#2fcaf5", marker = "o", linestyle = "none")
plt.axis('equal');

# %% [markdown]
# ##### Perímetro

# %%
center = [0.5,0.5]
radius = 0.2
nPoints = 10000
distanceType = DistanceType.AITCHINSON_DISTANCE
spSamp = SpaceSampler()


perimeterPoints = spSamp.samplePerimeterPoints(center,radius,nPoints, distanceType, epsilon = 0.01)

# %%
plt.figure()
plt.plot(perimeterPoints[:,0], perimeterPoints[:,1], color = "#2fcaf5", marker = "o", linestyle = "none")
plt.axis('equal');
